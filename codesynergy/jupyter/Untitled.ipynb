# %%
regions = [
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "001",
            "database": "netabc",
            "id": "61000",
            "name": "ARARUAMA",
            "state": "RJ"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "002",
            "database": "netsul",
            "id": "00272",
            "name": "MARABA",
            "state": "PA"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "003",
            "database": "netsp",
            "id": "88412",
            "name": "SAO PAULO",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "004",
            "database": "netbrasil",
            "id": "06139",
            "name": "SANTOS",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "005",
            "database": "netisp",
            "id": "06070",
            "name": "RIBEIRAO PRETO",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "006",
            "database": "netisp",
            "id": "06158",
            "name": "SAO JOSE DO RIO PRETO",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "007",
            "database": "netsorocaba",
            "id": "06201",
            "name": "SOROCABA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "absence"
            },
            "code": "008",
            "database": "netisp",
            "id": "05449",
            "name": "BAURU",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "009",
            "database": "netisp",
            "id": "05985",
            "name": "PIRACICABA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "mixed"
            },
            "code": "010",
            "database": "netbrasil",
            "id": "19887",
            "name": "GOIANIA",
            "state": "GO"
        },
        {
            "characteristics": {
                "numberIndicator": "mixed"
            },
            "code": "011",
            "database": "netisp",
            "id": "08533",
            "name": "CAMPO GRANDE",
            "state": "MS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "012",
            "database": "netsorocaba",
            "id": "82007",
            "name": "CAMPO LIMPO PAULISTA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "013",
            "database": "netbh",
            "id": "25666",
            "name": "BELO HORIZONTE",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "014",
            "database": "netisp",
            "id": "34010",
            "name": "PATOS DE MINAS",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "mixed"
            },
            "code": "015",
            "database": "netbrasil",
            "id": "18511",
            "name": "ANAPOLIS",
            "state": "GO"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "016",
            "database": "netsul",
            "id": "54011",
            "name": "ASTORGA",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "mixed"
            },
            "code": "017",
            "database": "netisp",
            "id": "41017",
            "name": "PONTA PORA",
            "state": "MS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "018",
            "database": "netsul",
            "id": "60003",
            "name": "SAO SEBASTIAO DA AMOREIRA",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "019",
            "database": "netsorocaba",
            "id": "81019",
            "name": "ASSIS",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "022",
            "database": "netsorocaba",
            "id": "06022",
            "name": "PORTO FELIZ",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "023",
            "database": "netsul",
            "id": "00233",
            "name": "CASTANHAL",
            "state": "PA"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "024",
            "database": "netsorocaba",
            "id": "06024",
            "name": "POTIM",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "025",
            "database": "netsorocaba",
            "id": "87025",
            "name": "PRESIDENTE BERNARDES",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "026",
            "database": "netsul",
            "id": "79022",
            "name": "TIMBO",
            "state": "SC"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "027",
            "database": "netabc",
            "id": "06027",
            "name": "PRAIA GRANDE",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "028",
            "database": "netabc",
            "id": "82023",
            "name": "CAMPOS DO JORDAO",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "030",
            "database": "netisp",
            "id": "05230",
            "name": "NOVA FRIBURGO",
            "state": "RJ"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "031",
            "database": "netbrasil",
            "id": "62030",
            "name": "ITABORAI",
            "state": "RJ"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "032",
            "database": "netisp",
            "id": "18031",
            "name": "SAO MATEUS",
            "state": "ES"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "034",
            "database": "netsorocaba",
            "id": "61034",
            "name": "ARRAIAL DO CABO",
            "state": "RJ"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "036",
            "database": "netisp",
            "id": "06036",
            "name": "PRESIDENTE PRUDENTE",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "037",
            "database": "netsul",
            "id": "04437",
            "name": "POCOS DE CALDAS",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "038",
            "database": "netbrasil",
            "id": "63118",
            "name": "RIO DE JANEIRO",
            "state": "RJ"
        },
        {
            "characteristics": {
                "numberIndicator": "absence"
            },
            "code": "040",
            "database": "netbrasil",
            "id": "15890",
            "name": "BRASILIA",
            "state": "DF"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "041",
            "database": "netsorocaba",
            "id": "73040",
            "name": "SANTANA DO LIVRAMENTO",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "042",
            "database": "netsorocaba",
            "id": "03042",
            "name": "LAURO DE FREITAS",
            "state": "BA"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "043",
            "database": "netisp",
            "id": "04143",
            "name": "LAGOA SANTA",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "044",
            "database": "netsorocaba",
            "id": "12041",
            "name": "EUSEBIO",
            "state": "CE"
        },
        {
            "characteristics": {
                "numberIndicator": "mixed"
            },
            "code": "047",
            "database": "netbrasil",
            "id": "22047",
            "name": "TRINDADE",
            "state": "GO"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "048",
            "database": "netsorocaba",
            "id": "06048",
            "name": "RAFARD",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "051",
            "database": "netsorocaba",
            "id": "23051",
            "name": "IMPERATRIZ",
            "state": "MA"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "052",
            "database": "netisp",
            "id": "05509",
            "name": "CAMPINAS",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "053",
            "database": "netisp",
            "id": "06144",
            "name": "SAO CARLOS",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "054",
            "database": "netisp",
            "id": "05693",
            "name": "INDAIATUBA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "055",
            "database": "netisp",
            "id": "05776",
            "name": "JUNDIAI",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "056",
            "database": "netisp",
            "id": "05623",
            "name": "FRANCA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "057",
            "database": "netsorocaba",
            "id": "62057",
            "name": "ITAGUAI",
            "state": "RJ"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "058",
            "database": "netsul",
            "id": "07058",
            "name": "BIGUACU",
            "state": "SC"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "060",
            "database": "netisp",
            "id": "04060",
            "name": "ITUIUTABA",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "061",
            "database": "netisp",
            "id": "05061",
            "name": "EUNAPOLIS",
            "state": "BA"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "063",
            "database": "netsorocaba",
            "id": "00863",
            "name": "TERESINA",
            "state": "PI"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "065",
            "database": "netsorocaba",
            "id": "10065",
            "name": "VALENCA",
            "state": "BA"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "066",
            "database": "netisp",
            "id": "00066",
            "name": "RIO BRANCO",
            "state": "AC"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "067",
            "database": "netisp",
            "id": "06067",
            "name": "RIBEIRAO PIRES",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "068",
            "database": "netsorocaba",
            "id": "76066",
            "name": "CHAPECO",
            "state": "SC"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "069",
            "database": "netsorocaba",
            "id": "53066",
            "name": "PARNAIBA",
            "state": "PI"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "070",
            "database": "netisp",
            "id": "07070",
            "name": "BRUSQUE",
            "state": "SC"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "071",
            "database": "netabc",
            "id": "86070",
            "name": "OURINHOS",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "072",
            "database": "netbrasil",
            "id": "36072",
            "name": "SANTA LUZIA",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "mixed"
            },
            "code": "073",
            "database": "netbrasil",
            "id": "19070",
            "name": "CALDAS NOVAS",
            "state": "GO"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "074",
            "database": "netisp",
            "id": "87068",
            "name": "PROMISSAO",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "075",
            "database": "netsul",
            "id": "72907",
            "name": "SANTA MARIA",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "076",
            "database": "netabc",
            "id": "06076",
            "name": "RIO CLARO",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "077",
            "database": "netsorocaba",
            "id": "73075",
            "name": "SANTO ANGELO",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "078",
            "database": "netsul",
            "id": "71986",
            "name": "PORTO ALEGRE - CABO",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "081",
            "database": "netsul",
            "id": "56081",
            "name": "GUARATUBA",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "082",
            "database": "netisp",
            "id": "27081",
            "name": "CARATINGA",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "083",
            "database": "netsul",
            "id": "69337",
            "name": "FARROUPILHA",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "084",
            "database": "netisp",
            "id": "06084",
            "name": "ITABUNA",
            "state": "BA"
        },
        {
            "characteristics": {
                "numberIndicator": "mixed"
            },
            "code": "085",
            "database": "netisp",
            "id": "21083",
            "name": "PARAISO DO TOCANTINS",
            "state": "TO"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "086",
            "database": "netsul",
            "id": "77127",
            "name": "JOINVILLE",
            "state": "SC"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "087",
            "database": "netsul",
            "id": "67784",
            "name": "CAPAO DA CANOA",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "088",
            "database": "netsul",
            "id": "76414",
            "name": "FLORIANOPOLIS",
            "state": "SC"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "089",
            "database": "netsul",
            "id": "76180",
            "name": "CRICIUMA",
            "state": "SC"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "090",
            "database": "netsul",
            "id": "79090",
            "name": "TUBARAO",
            "state": "SC"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "091",
            "database": "netsul",
            "id": "57304",
            "name": "MARINGA",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "092",
            "database": "netsorocaba",
            "id": "81086",
            "name": "AVARE",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "093",
            "database": "netsul",
            "id": "53902",
            "name": "ARAPONGAS",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "094",
            "database": "netisp",
            "id": "07194",
            "name": "ITAPEMA",
            "state": "SC"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "095",
            "database": "netsorocaba",
            "id": "01695",
            "name": "NATAL",
            "state": "RN"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "096",
            "database": "netsorocaba",
            "id": "00696",
            "name": "SAO LUIS",
            "state": "MA"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "097",
            "database": "netsorocaba",
            "id": "01097",
            "name": "FORTALEZA",
            "state": "CE"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "098",
            "database": "netisp",
            "id": "83097",
            "name": "FERNANDOPOLIS",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "099",
            "database": "netisp",
            "id": "33090",
            "name": "MURIAE",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "100",
            "database": "netabc",
            "id": "05100",
            "name": "BARRA MANSA",
            "state": "RJ"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "101",
            "database": "netsul",
            "id": "60097",
            "name": "SARANDI",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "103",
            "database": "netabc",
            "id": "06103",
            "name": "SANTA BARBARA D OESTE",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "104",
            "database": "netabc",
            "id": "06104",
            "name": "SANTA BRANCA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "105",
            "database": "netsorocaba",
            "id": "05105",
            "name": "BELFORD ROXO",
            "state": "RJ"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "106",
            "database": "netsul",
            "id": "70106",
            "name": "ITAQUI",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "108",
            "database": "netabc",
            "id": "06108",
            "name": "SANTA CRUZ DO RIO PARDO",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "110",
            "database": "netsorocaba",
            "id": "13110",
            "name": "JUAZEIRO DO NORTE",
            "state": "CE"
        },
        {
            "characteristics": {
                "numberIndicator": "mixed"
            },
            "code": "112",
            "database": "netsul",
            "id": "09112",
            "name": "RIO VERDE",
            "state": "GO"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "113",
            "database": "netsul",
            "id": "76112",
            "name": "CONCORDIA",
            "state": "SC"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "114",
            "database": "netsul",
            "id": "58114",
            "name": "PATO BRANCO",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "115",
            "database": "netsul",
            "id": "05115",
            "name": "CABO FRIO",
            "state": "RJ"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "116",
            "database": "netabc",
            "id": "05116",
            "name": "ARMACAO DOS BUZIOS",
            "state": "RJ"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "119",
            "database": "netsul",
            "id": "77119",
            "name": "JOACABA",
            "state": "SC"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "121",
            "database": "netabc",
            "id": "00121",
            "name": "MANAUS",
            "state": "AM"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "124",
            "database": "netisp",
            "id": "81124",
            "name": "BADY BASSITT",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "126",
            "database": "netisp",
            "id": "04126",
            "name": "JUIZ DE FORA",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "129",
            "database": "netabc",
            "id": "06129",
            "name": "SANTO ANDRE",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "131",
            "database": "netsul",
            "id": "55131",
            "name": "CORNELIO PROCOPIO",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "133",
            "database": "netisp",
            "id": "01833",
            "name": "CABEDELO",
            "state": "PB"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "136",
            "database": "netabc",
            "id": "51136",
            "name": "RECIFE",
            "state": "PE"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "138",
            "database": "netabc",
            "id": "85138",
            "name": "MAIRIPORA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "141",
            "database": "netabc",
            "id": "06141",
            "name": "SAO BERNARDO DO CAMPO",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "143",
            "database": "netabc",
            "id": "06143",
            "name": "SAO CAETANO DO SUL",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "144",
            "database": "netisp",
            "id": "31143",
            "name": "ITAUNA",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "151",
            "database": "netisp",
            "id": "25151",
            "name": "ARAXA",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "152",
            "database": "netisp",
            "id": "02152",
            "name": "CARUARU",
            "state": "PE"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "154",
            "database": "netisp",
            "id": "07154",
            "name": "GASPAR",
            "state": "SC"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "156",
            "database": "netabc",
            "id": "00156",
            "name": "BOA VISTA",
            "state": "RR"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "158",
            "database": "netisp",
            "id": "61158",
            "name": "BARRA DO PIRAI",
            "state": "RJ"
        },
        {
            "characteristics": {
                "numberIndicator": "mixed"
            },
            "code": "160",
            "database": "netbrasil",
            "id": "22160",
            "name": "VALPARAISO DE GOIAS",
            "state": "GO"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "161",
            "database": "netsorocaba",
            "id": "05161",
            "name": "DUQUE DE CAXIAS",
            "state": "RJ"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "162",
            "database": "netabc",
            "id": "06162",
            "name": "SAO JOSE DOS CAMPOS",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "163",
            "database": "netsul",
            "id": "07163",
            "name": "GUARAMIRIM",
            "state": "SC"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "164",
            "database": "netsorocaba",
            "id": "39160",
            "name": "UBA",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "mixed"
            },
            "code": "165",
            "database": "netsorocaba",
            "id": "24163",
            "name": "TIMON",
            "state": "MA"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "166",
            "database": "netabc",
            "id": "84166",
            "name": "ITAPEVA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "167",
            "database": "netisp",
            "id": "16160",
            "name": "ARACRUZ",
            "state": "ES"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "168",
            "database": "netsorocaba",
            "id": "89168",
            "name": "TUPA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "169",
            "database": "netisp",
            "id": "26166",
            "name": "BRASILIA DE MINAS",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "171",
            "database": "netsul",
            "id": "06171",
            "name": "SAO MIGUEL ARCANJO",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "173",
            "database": "netsul",
            "id": "70173",
            "name": "IVOTI",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "178",
            "database": "netsorocaba",
            "id": "00178",
            "name": "ANANINDEUA",
            "state": "PA"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "181",
            "database": "netisp",
            "id": "29181",
            "name": "ESMERALDAS",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "182",
            "database": "netabc",
            "id": "06182",
            "name": "SAO SEBASTIAO",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "183",
            "database": "netabc",
            "id": "84182",
            "name": "ITAPIRA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "186",
            "database": "netisp",
            "id": "25186",
            "name": "ARCOS",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "187",
            "database": "netabc",
            "id": "06187",
            "name": "SAO VICENTE",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "193",
            "database": "netisp",
            "id": "07193",
            "name": "ITAJAI",
            "state": "SC"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "194",
            "database": "netsorocaba",
            "id": "00194",
            "name": "BELEM",
            "state": "PA"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "195",
            "database": "netsorocaba",
            "id": "06195",
            "name": "SERTAOZINHO",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "197",
            "database": "netisp",
            "id": "05197",
            "name": "MACAE",
            "state": "RJ"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "200",
            "database": "netabc",
            "id": "88200",
            "name": "SAO JOAO DA BOA VISTA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "201",
            "database": "netsul",
            "id": "71200",
            "name": "NOVA PETROPOLIS",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "202",
            "database": "netsorocaba",
            "id": "82201",
            "name": "CASA BRANCA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "203",
            "database": "netsul",
            "id": "07203",
            "name": "JARAGUA DO SUL",
            "state": "SC"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "204",
            "database": "netsul",
            "id": "56200",
            "name": "IBIPORA",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "206",
            "database": "netisp",
            "id": "66206",
            "name": "VILHENA",
            "state": "RO"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "207",
            "database": "netabc",
            "id": "06207",
            "name": "SUMARE",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "208",
            "database": "netsorocaba",
            "id": "57207",
            "name": "MARECHAL CANDIDO RONDON",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "209",
            "database": "netisp",
            "id": "06209",
            "name": "SUZANO",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "211",
            "database": "netsorocaba",
            "id": "87211",
            "name": "REGISTRO",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "213",
            "database": "netsul",
            "id": "07213",
            "name": "LAGES",
            "state": "SC"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "214",
            "database": "netsorocaba",
            "id": "00213",
            "name": "ARAPIRACA",
            "state": "AL"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "216",
            "database": "netsorocaba",
            "id": "06216",
            "name": "TABOAO DA SERRA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "217",
            "database": "netsul",
            "id": "68217",
            "name": "CHARQUEADAS",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "220",
            "database": "netisp",
            "id": "00022",
            "name": "PORTO VELHO",
            "state": "RO"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "221",
            "database": "netsorocaba",
            "id": "17221",
            "name": "LINHARES",
            "state": "ES"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "222",
            "database": "netisp",
            "id": "32220",
            "name": "MANHUACU",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "223",
            "database": "netabc",
            "id": "02235",
            "name": "JABOATAO DOS GUARARAPES",
            "state": "PE"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "226",
            "database": "netsorocaba",
            "id": "05226",
            "name": "NILOPOLIS",
            "state": "RJ"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "228",
            "database": "netbrasil",
            "id": "05228",
            "name": "NITEROI",
            "state": "RJ"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "229",
            "database": "netsul",
            "id": "73229",
            "name": "SAO BORJA",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "230",
            "database": "netsorocaba",
            "id": "03230",
            "name": "SALVADOR",
            "state": "BA"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "231",
            "database": "netsul",
            "id": "69230",
            "name": "ESTRELA",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "232",
            "database": "netsorocaba",
            "id": "83232",
            "name": "GARCA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "233",
            "database": "netsul",
            "id": "06233",
            "name": "TATUI",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "234",
            "database": "netisp",
            "id": "34231",
            "name": "PEDRO LEOPOLDO",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "235",
            "database": "netabc",
            "id": "06235",
            "name": "TAUBATE",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "236",
            "database": "netsorocaba",
            "id": "79235",
            "name": "VIDEIRA",
            "state": "SC"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "237",
            "database": "netsorocaba",
            "id": "05237",
            "name": "NOVA IGUACU",
            "state": "RJ"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "239",
            "database": "netsorocaba",
            "id": "05239",
            "name": "MESQUITA",
            "state": "RJ"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "241",
            "database": "netsorocaba",
            "id": "06241",
            "name": "TIETE",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "242",
            "database": "netsorocaba",
            "id": "74241",
            "name": "TAQUARA",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "246",
            "database": "netsul",
            "id": "06246",
            "name": "TREMEMBE",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "250",
            "database": "netisp",
            "id": "05250",
            "name": "PETROPOLIS",
            "state": "RJ"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "251",
            "database": "netisp",
            "id": "39250",
            "name": "UNAI",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "255",
            "database": "netisp",
            "id": "61255",
            "name": "BOM JARDIM",
            "state": "RJ"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "256",
            "database": "netsorocaba",
            "id": "81256",
            "name": "BARRA BONITA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "mixed"
            },
            "code": "257",
            "database": "netbrasil",
            "id": "20257",
            "name": "ITUMBIARA",
            "state": "GO"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "260",
            "database": "netisp",
            "id": "07260",
            "name": "NAVEGANTES",
            "state": "SC"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "261",
            "database": "netabc",
            "id": "06261",
            "name": "UBATUBA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "268",
            "database": "netabc",
            "id": "05268",
            "name": "RESENDE",
            "state": "RJ"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "269",
            "database": "netabc",
            "id": "02269",
            "name": "OLINDA",
            "state": "PE"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "270",
            "database": "netsul",
            "id": "73270",
            "name": "SAO GABRIEL",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "272",
            "database": "netsorocaba",
            "id": "06272",
            "name": "VALINHOS",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "273",
            "database": "netisp",
            "id": "37273",
            "name": "SAO JOAO DEL REI",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "274",
            "database": "netsul",
            "id": "36277",
            "name": "SANTA RITA DO SAPUCAI",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "275",
            "database": "netisp",
            "id": "04275",
            "name": "MONTES CLAROS",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "276",
            "database": "netsorocaba",
            "id": "06276",
            "name": "VARGEM GRANDE PAULISTA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "277",
            "database": "netsul",
            "id": "06277",
            "name": "VARZEA PAULISTA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "278",
            "database": "netisp",
            "id": "07278",
            "name": "PALHOCA",
            "state": "SC"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "279",
            "database": "netsul",
            "id": "06279",
            "name": "VINHEDO",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "282",
            "database": "netsul",
            "id": "06282",
            "name": "VOTORANTIM",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "283",
            "database": "netbrasil",
            "id": "19283",
            "name": "CATALAO",
            "state": "GO"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "285",
            "database": "netisp",
            "id": "05285",
            "name": "RIO DAS OSTRAS",
            "state": "RJ"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "286",
            "database": "netisp",
            "id": "62286",
            "name": "MAGE",
            "state": "RJ"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "291",
            "database": "netabc",
            "id": "02291",
            "name": "PAULISTA",
            "state": "PE"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "293",
            "database": "netsul",
            "id": "71293",
            "name": "OSORIO",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "294",
            "database": "netisp",
            "id": "06294",
            "name": "ALMIRANTE TAMANDARE",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "295",
            "database": "netsorocaba",
            "id": "06095",
            "name": "SALTO",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "296",
            "database": "netsorocaba",
            "id": "82295",
            "name": "CERQUILHO",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "297",
            "database": "netabc",
            "id": "85294",
            "name": "MATAO",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "300",
            "database": "netisp",
            "id": "32301",
            "name": "MARIANA",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "301",
            "database": "netsul",
            "id": "78301",
            "name": "RIO DO SUL",
            "state": "SC"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "302",
            "database": "netsorocaba",
            "id": "81302",
            "name": "BARRETOS",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "mixed"
            },
            "code": "303",
            "database": "netbrasil",
            "id": "20303",
            "name": "JATAI",
            "state": "GO"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "304",
            "database": "netsorocaba",
            "id": "40304",
            "name": "CORUMBA",
            "state": "MS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "305",
            "database": "netisp",
            "id": "05305",
            "name": "SAO GONCALO",
            "state": "RJ"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "308",
            "database": "netabc",
            "id": "62308",
            "name": "MANGARATIBA",
            "state": "RJ"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "312",
            "database": "netisp",
            "id": "04312",
            "name": "NOVA LIMA",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "315",
            "database": "netsorocaba",
            "id": "88315",
            "name": "SAO JOSE DO RIO PARDO",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "316",
            "database": "netsorocaba",
            "id": "05316",
            "name": "SAO JOAO DE MERITI",
            "state": "RJ"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "320",
            "database": "netsul",
            "id": "05320",
            "name": "SAO PEDRO DA ALDEIA",
            "state": "RJ"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "322",
            "database": "netsul",
            "id": "06322",
            "name": "APUCARANA",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "323",
            "database": "netsorocaba",
            "id": "80322",
            "name": "ADAMANTINA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "324",
            "database": "netsul",
            "id": "74322",
            "name": "TEUTONIA",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "330",
            "database": "netisp",
            "id": "08330",
            "name": "SAPIRANGA",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "331",
            "database": "netsorocaba",
            "id": "60330",
            "name": "TELEMACO BORBA",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "332",
            "database": "netisp",
            "id": "08332",
            "name": "SAPUCAIA DO SUL",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "333",
            "database": "netisp",
            "id": "06333",
            "name": "ARAUCARIA",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "334",
            "database": "netsorocaba",
            "id": "79332",
            "name": "XANXERE",
            "state": "SC"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "335",
            "database": "netisp",
            "id": "33332",
            "name": "NOVA SERRANA",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "336",
            "database": "netisp",
            "id": "03363",
            "name": "VITORIA DA CONQUISTA",
            "state": "BA"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "338",
            "database": "netisp",
            "id": "05338",
            "name": "TERESOPOLIS",
            "state": "RJ"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "340",
            "database": "netisp",
            "id": "27340",
            "name": "CATAGUASES",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "mixed"
            },
            "code": "341",
            "database": "netabc",
            "id": "42340",
            "name": "NOVA MUTUM",
            "state": "MT"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "348",
            "database": "netsorocaba",
            "id": "77348",
            "name": "MAFRA",
            "state": "SC"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "350",
            "database": "netisp",
            "id": "30350",
            "name": "GUAXUPE",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "352",
            "database": "netsorocaba",
            "id": "78352",
            "name": "RIO NEGRINHO",
            "state": "SC"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "353",
            "database": "netsorocaba",
            "id": "03352",
            "name": "BARREIRAS",
            "state": "BA"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "359",
            "database": "netisp",
            "id": "05359",
            "name": "VOLTA REDONDA",
            "state": "RJ"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "360",
            "database": "netsorocaba",
            "id": "84360",
            "name": "ITUPEVA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "361",
            "database": "netsorocaba",
            "id": "79359",
            "name": "XAXIM",
            "state": "SC"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "362",
            "database": "netisp",
            "id": "89362",
            "name": "VALPARAISO",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "363",
            "database": "netisp",
            "id": "07363",
            "name": "SAO JOSE",
            "state": "SC"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "364",
            "database": "netisp",
            "id": "83364",
            "name": "GUAIRA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "365",
            "database": "netabc",
            "id": "80365",
            "name": "AGUAI",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "367",
            "database": "netisp",
            "id": "62367",
            "name": "MARICA",
            "state": "RJ"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "378",
            "database": "netabc",
            "id": "41378",
            "name": "TRES LAGOAS",
            "state": "MS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "379",
            "database": "netsul",
            "id": "06379",
            "name": "CAMBE",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "380",
            "database": "netsul",
            "id": "58378",
            "name": "PIRAQUARA",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "381",
            "database": "netisp",
            "id": "83380",
            "name": "GUAPIACU",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "382",
            "database": "netsul",
            "id": "29378",
            "name": "EXTREMA",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "386",
            "database": "netabc",
            "id": "05386",
            "name": "AMERICANA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "388",
            "database": "netisp",
            "id": "81388",
            "name": "BEBEDOURO",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "389",
            "database": "netisp",
            "id": "06389",
            "name": "CAMPO LARGO",
            "state": "PR"
        },
        {
            "code": "39",
            "database": "netisp",
            "id": "34037",
            "name": "PATROCINIO",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "390",
            "database": "netsorocaba",
            "id": "66389",
            "name": "ALEGRETE",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "391",
            "database": "netisp",
            "id": "62391",
            "name": "MIGUEL PEREIRA",
            "state": "RJ"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "392",
            "database": "netisp",
            "id": "85391",
            "name": "MIRANDOPOLIS",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "393",
            "database": "netsul",
            "id": "00393",
            "name": "MACAPA",
            "state": "AP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "394",
            "database": "netsorocaba",
            "id": "67393",
            "name": "CACHOEIRA DO SUL",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "395",
            "database": "netisp",
            "id": "06394",
            "name": "ITAPETINGA",
            "state": "BA"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "398",
            "database": "netsul",
            "id": "08398",
            "name": "TORRES",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "399",
            "database": "netsorocaba",
            "id": "05399",
            "name": "APARECIDA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "400",
            "database": "netsul",
            "id": "75400",
            "name": "ARARANGUA",
            "state": "SC"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "401",
            "database": "netsul",
            "id": "57401",
            "name": "MATINHOS",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "402",
            "database": "netsul",
            "id": "04024",
            "name": "ITAJUBA",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "404",
            "database": "netabc",
            "id": "05404",
            "name": "ARACATUBA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "405",
            "database": "netisp",
            "id": "04005",
            "name": "IPATINGA",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "408",
            "database": "netabc",
            "id": "87408",
            "name": "RIO GRANDE DA SERRA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "409",
            "database": "netabc",
            "id": "05409",
            "name": "ARARAQUARA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "410",
            "database": "netisp",
            "id": "84409",
            "name": "JABOTICABAL",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "411",
            "database": "netsorocaba",
            "id": "80411",
            "name": "AGUDOS",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "412",
            "database": "netsul",
            "id": "71412",
            "name": "PALMEIRA DAS MISSOES",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "413",
            "database": "netabc",
            "id": "05413",
            "name": "ARARAS",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "415",
            "database": "netsorocaba",
            "id": "09415",
            "name": "SENHOR DO BONFIM",
            "state": "BA"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "419",
            "database": "netisp",
            "id": "05419",
            "name": "ARTUR NOGUEIRA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "420",
            "database": "netsul",
            "id": "05420",
            "name": "ARUJA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "421",
            "database": "netisp",
            "id": "79421",
            "name": "BARRA DOS COQUEIROS",
            "state": "SE"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "422",
            "database": "netsul",
            "id": "27421",
            "name": "CAXAMBU",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "423",
            "database": "netabc",
            "id": "05423",
            "name": "ATIBAIA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "428",
            "database": "netsorocaba",
            "id": "57428",
            "name": "MEDIANEIRA",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "430",
            "database": "netsorocaba",
            "id": "06430",
            "name": "CIANORTE",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "431",
            "database": "netsorocaba",
            "id": "85430",
            "name": "MOCOCA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "432",
            "database": "netabc",
            "id": "82430",
            "name": "CORDEIROPOLIS",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "437",
            "database": "netisp",
            "id": "06437",
            "name": "COLOMBO",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "438",
            "database": "netsul",
            "id": "74438",
            "name": "TRAMANDAI",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "439",
            "database": "netsorocaba",
            "id": "60437",
            "name": "TOLEDO",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "442",
            "database": "netabc",
            "id": "05442",
            "name": "BARRINHA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "443",
            "database": "netsorocaba",
            "id": "05443",
            "name": "BARUERI",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "444",
            "database": "netsorocaba",
            "id": "89443",
            "name": "VERA CRUZ",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "445",
            "database": "netbrasil",
            "id": "20443",
            "name": "LUZIANIA",
            "state": "GO"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "447",
            "database": "netsul",
            "id": "71447",
            "name": "PANAMBI",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "448",
            "database": "netsul",
            "id": "05448",
            "name": "BATATAIS",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "449",
            "database": "netsorocaba",
            "id": "76449",
            "name": "FRAIBURGO",
            "state": "SC"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "450",
            "database": "netabc",
            "id": "81450",
            "name": "BIRIGUI",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "455",
            "database": "netisp",
            "id": "03455",
            "name": "ARAGUARI",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "456",
            "database": "netabc",
            "id": "05456",
            "name": "BERTIOGA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "458",
            "database": "netsul",
            "id": "07458",
            "name": "ALVORADA",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "459",
            "database": "netsul",
            "id": "04459",
            "name": "POUSO ALEGRE",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "464",
            "database": "netabc",
            "id": "05464",
            "name": "BOITUVA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "466",
            "database": "netsul",
            "id": "67466",
            "name": "CAMAQUA",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "468",
            "database": "netisp",
            "id": "61468",
            "name": "CASIMIRO DE ABREU",
            "state": "RJ"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "470",
            "database": "netisp",
            "id": "25470",
            "name": "BARBACENA",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "471",
            "database": "netsorocaba",
            "id": "05471",
            "name": "BOTUCATU",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "474",
            "database": "netabc",
            "id": "05474",
            "name": "BRAGANCA PAULISTA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "477",
            "database": "netabc",
            "id": "04770",
            "name": "TIMOTEO",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "478",
            "database": "netsul",
            "id": "72478",
            "name": "RIO PARDO",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "480",
            "database": "netsorocaba",
            "id": "02480",
            "name": "MACEIO",
            "state": "AL"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "481",
            "database": "netisp",
            "id": "07480",
            "name": "MATA DE SAO JOAO",
            "state": "BA"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "482",
            "database": "netsul",
            "id": "73482",
            "name": "SAO LOURENCO DO SUL",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "487",
            "database": "netabc",
            "id": "05487",
            "name": "CACAPAVA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "488",
            "database": "netsorocaba",
            "id": "05488",
            "name": "CACHOEIRA PAULISTA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "489",
            "database": "netisp",
            "id": "16489",
            "name": "COLATINA",
            "state": "ES"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "491",
            "database": "netisp",
            "id": "32492",
            "name": "MATOZINHOS",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "492",
            "database": "netabc",
            "id": "84492",
            "name": "JALES",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "493",
            "database": "netsul",
            "id": "08493",
            "name": "XANGRI-LA",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "495",
            "database": "netabc",
            "id": "86495",
            "name": "PENAPOLIS",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "496",
            "database": "netisp",
            "id": "83496",
            "name": "GUARARAPES",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "497",
            "database": "netsul",
            "id": "74497",
            "name": "TRES COROAS",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "498",
            "database": "netsul",
            "id": "05498",
            "name": "CAIEIRAS",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "499",
            "database": "netsorocaba",
            "id": "71498",
            "name": "PAROBE",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "500",
            "database": "netsul",
            "id": "74500",
            "name": "TRES DE MAIO",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "504",
            "database": "netsul",
            "id": "73504",
            "name": "SAO LUIZ GONZAGA",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "505",
            "database": "netisp",
            "id": "09504",
            "name": "SIMOES FILHO",
            "state": "BA"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "506",
            "database": "netsul",
            "id": "06506",
            "name": "FOZ DO IGUACU",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "507",
            "database": "netsorocaba",
            "id": "05078",
            "name": "VILA VELHA",
            "state": "ES"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "508",
            "database": "netsorocaba",
            "id": "05083",
            "name": "VITORIA",
            "state": "ES"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "509",
            "database": "netabc",
            "id": "86509",
            "name": "PEREIRA BARRETO",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "514",
            "database": "netisp",
            "id": "03514",
            "name": "BETIM",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "520",
            "database": "netbrasil",
            "id": "30520",
            "name": "IBIRITE",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "521",
            "database": "netsul",
            "id": "01521",
            "name": "SOBRAL",
            "state": "CE"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "526",
            "database": "netisp",
            "id": "31526",
            "name": "JOAO MONLEVADE",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "529",
            "database": "netisp",
            "id": "05129",
            "name": "CAMPOS DOS GOYTACAZES",
            "state": "RJ"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "530",
            "database": "netsorocaba",
            "id": "05530",
            "name": "CAPIVARI",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "531",
            "database": "netsorocaba",
            "id": "06531",
            "name": "GUARAPUAVA",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "532",
            "database": "netisp",
            "id": "08532",
            "name": "PORTO SEGURO",
            "state": "BA"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "533",
            "database": "netsorocaba",
            "id": "05533",
            "name": "CARAPICUIBA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "534",
            "database": "netisp",
            "id": "85529",
            "name": "MONTE ALTO",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "535",
            "database": "netsorocaba",
            "id": "80535",
            "name": "ALUMINIO",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "536",
            "database": "netsul",
            "id": "69531",
            "name": "FREDERICO WESTPHALEN",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "537",
            "database": "netisp",
            "id": "33537",
            "name": "OURO PRETO",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "538",
            "database": "netabc",
            "id": "05389",
            "name": "AMPARO",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "mixed"
            },
            "code": "540",
            "database": "netisp",
            "id": "00540",
            "name": "PALMAS",
            "state": "TO"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "541",
            "database": "netisp",
            "id": "04541",
            "name": "SABARA",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "542",
            "database": "netisp",
            "id": "28541",
            "name": "CURVELO",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "543",
            "database": "netsul",
            "id": "05543",
            "name": "CATANDUVA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "545",
            "database": "netabc",
            "id": "05405",
            "name": "ARACOIABA DA SERRA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "550",
            "database": "netisp",
            "id": "02550",
            "name": "ARACAJU",
            "state": "SE"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "551",
            "database": "netsorocaba",
            "id": "80551",
            "name": "ALVARES MACHADO",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "552",
            "database": "netsul",
            "id": "63550",
            "name": "SAQUAREMA",
            "state": "RJ"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "553",
            "database": "netabc",
            "id": "05531",
            "name": "CARAGUATATUBA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "559",
            "database": "netisp",
            "id": "89559",
            "name": "VOTUPORANGA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "560",
            "database": "netsul",
            "id": "07560",
            "name": "CACHOEIRINHA",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "561",
            "database": "netsorocaba",
            "id": "10561",
            "name": "AQUIRAZ",
            "state": "CE"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "565",
            "database": "netisp",
            "id": "05565",
            "name": "COSMOPOLIS",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "566",
            "database": "netisp",
            "id": "05066",
            "name": "SERRA",
            "state": "ES"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "567",
            "database": "netsorocaba",
            "id": "05567",
            "name": "COTIA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "568",
            "database": "netsul",
            "id": "69566",
            "name": "GARIBALDI",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "569",
            "database": "netabc",
            "id": "05569",
            "name": "CRAVINHOS",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "570",
            "database": "netsorocaba",
            "id": "78565",
            "name": "SAO BENTO DO SUL",
            "state": "SC"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "571",
            "database": "netsorocaba",
            "id": "86568",
            "name": "PIEDADE",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "572",
            "database": "netsorocaba",
            "id": "05572",
            "name": "CRUZEIRO",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "573",
            "database": "netabc",
            "id": "05573",
            "name": "CUBATAO",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "574",
            "database": "netabc",
            "id": "05749",
            "name": "ITUVERAVA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "575",
            "database": "netisp",
            "id": "84573",
            "name": "JARDINOPOLIS",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "576",
            "database": "netabc",
            "id": "05576",
            "name": "DESCALVADO",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "577",
            "database": "netabc",
            "id": "05577",
            "name": "DIADEMA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "579",
            "database": "netabc",
            "id": "88579",
            "name": "SERRA NEGRA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "mixed"
            },
            "code": "580",
            "database": "netsul",
            "id": "21580",
            "name": "SANTA HELENA DE GOIAS",
            "state": "GO"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "581",
            "database": "netabc",
            "id": "84581",
            "name": "JARINU",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "584",
            "database": "netisp",
            "id": "07584",
            "name": "CAMPO BOM",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "585",
            "database": "netsul",
            "id": "60585",
            "name": "UMUARAMA",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "586",
            "database": "netsul",
            "id": "05586",
            "name": "DRACENA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "587",
            "database": "netsorocaba",
            "id": "88587",
            "name": "SERRANA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "588",
            "database": "netisp",
            "id": "39586",
            "name": "VICOSA",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "592",
            "database": "netabc",
            "id": "05923",
            "name": "ORLANDIA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "593",
            "database": "netsul",
            "id": "60593",
            "name": "UNIAO DA VITORIA",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "595",
            "database": "netsorocaba",
            "id": "05595",
            "name": "ELIAS FAUSTO",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "598",
            "database": "netisp",
            "id": "06599",
            "name": "JACOBINA",
            "state": "BA"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "599",
            "database": "netsorocaba",
            "id": "05599",
            "name": "EMBU DAS ARTES",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "600",
            "database": "netsul",
            "id": "24600",
            "name": "ALFENAS",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "601",
            "database": "netsul",
            "id": "07601",
            "name": "CANELA",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "603",
            "database": "netisp",
            "id": "07603",
            "name": "CANOAS",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "604",
            "database": "netsul",
            "id": "55603",
            "name": "FAZENDA RIO GRANDE",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "606",
            "database": "netabc",
            "id": "06096",
            "name": "SALTO DE PIRAPORA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "609",
            "database": "netisp",
            "id": "06009",
            "name": "POA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "612",
            "database": "netsul",
            "id": "37613",
            "name": "SAO LOURENCO",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "613",
            "database": "netsul",
            "id": "72613",
            "name": "ROSARIO DO SUL",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "614",
            "database": "netsul",
            "id": "07614",
            "name": "CARAZINHO",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "615",
            "database": "netabc",
            "id": "06154",
            "name": "SAO JOAQUIM DA BARRA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "616",
            "database": "netsul",
            "id": "02615",
            "name": "SANTANA",
            "state": "AP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "617",
            "database": "netisp",
            "id": "63614",
            "name": "SILVA JARDIM",
            "state": "RJ"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "618",
            "database": "netsul",
            "id": "66613",
            "name": "ARROIO DO MEIO",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "620",
            "database": "netsul",
            "id": "78620",
            "name": "SAO FRANCISCO DO SUL",
            "state": "SC"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "621",
            "database": "netsorocaba",
            "id": "06121",
            "name": "SANTANA DE PARNAIBA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "622",
            "database": "netsorocaba",
            "id": "11622",
            "name": "CAUCAIA",
            "state": "CE"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "624",
            "database": "netabc",
            "id": "80624",
            "name": "AMERICO BRASILIENSE",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "626",
            "database": "netisp",
            "id": "85626",
            "name": "MORUNGABA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "628",
            "database": "netsorocaba",
            "id": "44628",
            "name": "PARAGOMINAS",
            "state": "PA"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "634",
            "database": "netsul",
            "id": "56634",
            "name": "JANDAIA DO SUL",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "635",
            "database": "netisp",
            "id": "24635",
            "name": "ALMENARA",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "637",
            "database": "netsorocaba",
            "id": "01637",
            "name": "PARNAMIRIM",
            "state": "RN"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "638",
            "database": "netsul",
            "id": "70637",
            "name": "MARAU",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "641",
            "database": "netsorocaba",
            "id": "06413",
            "name": "CASCAVEL",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "645",
            "database": "netsul",
            "id": "41645",
            "name": "BARRA DO GARCAS",
            "state": "MT"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "654",
            "database": "netsorocaba",
            "id": "49654",
            "name": "GARANHUNS",
            "state": "PE"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "656",
            "database": "netsorocaba",
            "id": "05656",
            "name": "GUARATINGUETA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "657",
            "database": "netabc",
            "id": "86657",
            "name": "PIRACAIA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "659",
            "database": "netabc",
            "id": "05659",
            "name": "GUARUJA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "661",
            "database": "netsorocaba",
            "id": "05661",
            "name": "GUARULHOS",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "662",
            "database": "netisp",
            "id": "84662",
            "name": "JOSE BONIFACIO",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "666",
            "database": "netsul",
            "id": "54666",
            "name": "CAMPINA GRANDE DO SUL",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "668",
            "database": "netabc",
            "id": "05668",
            "name": "HORTOLANDIA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "669",
            "database": "netsorocaba",
            "id": "62669",
            "name": "PARACAMBI",
            "state": "RJ"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "670",
            "database": "netisp",
            "id": "29670",
            "name": "FORMIGA",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "674",
            "database": "netisp",
            "id": "83674",
            "name": "IBATE",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "mixed"
            },
            "code": "677",
            "database": "netisp",
            "id": "62677",
            "name": "PARAIBA DO SUL",
            "state": "RJ"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "678",
            "database": "netsul",
            "id": "06178",
            "name": "SAO ROQUE",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "mixed"
            },
            "code": "679",
            "database": "netisp",
            "id": "18678",
            "name": "ARAGUAINA",
            "state": "TO"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "681",
            "database": "netisp",
            "id": "28681",
            "name": "DIAMANTINA",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "683",
            "database": "netsul",
            "id": "58688",
            "name": "QUATRO BARRAS",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "684",
            "database": "netsul",
            "id": "74748",
            "name": "URUGUAIANA",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "685",
            "database": "netsul",
            "id": "68659",
            "name": "CRUZ ALTA",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "686",
            "database": "netsul",
            "id": "71242",
            "name": "NOVO HAMBURGO - CABO",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "687",
            "database": "netsul",
            "id": "68020",
            "name": "CAXIAS DO SUL",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "688",
            "database": "netsul",
            "id": "67040",
            "name": "BENTO GONCALVES",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "689",
            "database": "netsul",
            "id": "70408",
            "name": "LAJEADO",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "690",
            "database": "netsul",
            "id": "66770",
            "name": "BAGE",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "691",
            "database": "netsul",
            "id": "71706",
            "name": "PELOTAS",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "692",
            "database": "netsul",
            "id": "72451",
            "name": "RIO GRANDE",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "693",
            "database": "netsul",
            "id": "71587",
            "name": "PASSO FUNDO",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "694",
            "database": "netsul",
            "id": "72842",
            "name": "SANTA CRUZ DO SUL",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "695",
            "database": "netsul",
            "id": "69019",
            "name": "ERECHIM",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "697",
            "database": "netabc",
            "id": "80691",
            "name": "ANDRADINA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "700",
            "database": "netsul",
            "id": "75680",
            "name": "BLUMENAU",
            "state": "SC"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "701",
            "database": "netsul",
            "id": "55700",
            "name": "FLORESTA",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "710",
            "database": "netisp",
            "id": "89710",
            "name": "SAO LEOPOLDO - CABO",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "712",
            "database": "netabc",
            "id": "05712",
            "name": "ITANHAEM",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "713",
            "database": "netsorocaba",
            "id": "22713",
            "name": "CAXIAS",
            "state": "MA"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "714",
            "database": "netsorocaba",
            "id": "05714",
            "name": "ITAPECERICA DA SERRA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "715",
            "database": "netabc",
            "id": "05715",
            "name": "ITAPETININGA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "716",
            "database": "netsul",
            "id": "54712",
            "name": "CAMPO MAGRO",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "718",
            "database": "netisp",
            "id": "06718",
            "name": "JEQUIE",
            "state": "BA"
        },
        {
            "characteristics": {
                "numberIndicator": "mixed"
            },
            "code": "719",
            "database": "netsorocaba",
            "id": "08719",
            "name": "CUIABA",
            "state": "MT"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "720",
            "database": "netisp",
            "id": "07820",
            "name": "GRAVATAI",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "721",
            "database": "netsul",
            "id": "54720",
            "name": "CAMPO MOURAO",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "722",
            "database": "netsorocaba",
            "id": "05722",
            "name": "ITAPEVI",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "724",
            "database": "netsul",
            "id": "76724",
            "name": "ICARA",
            "state": "SC"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "728",
            "database": "netsorocaba",
            "id": "69728",
            "name": "GUAIBA",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "733",
            "database": "netisp",
            "id": "05733",
            "name": "ITAQUAQUECETUBA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "739",
            "database": "netsul",
            "id": "05739",
            "name": "ITATIBA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "741",
            "database": "netisp",
            "id": "03741",
            "name": "CONSELHEIRO LAFAIETE",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "742",
            "database": "netisp",
            "id": "04742",
            "name": "SETE LAGOAS",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "743",
            "database": "netisp",
            "id": "87742",
            "name": "SANTA CRUZ DAS PALMEIRAS",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "mixed"
            },
            "code": "745",
            "database": "netsul",
            "id": "89745",
            "name": "PARAUAPEBAS",
            "state": "PA"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "746",
            "database": "netabc",
            "id": "05746",
            "name": "ITU",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "747",
            "database": "netabc",
            "id": "86746",
            "name": "PIRASSUNUNGA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "749",
            "database": "netsul",
            "id": "06749",
            "name": "PARANAGUA",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "750",
            "database": "netisp",
            "id": "02750",
            "name": "CAMACARI",
            "state": "BA"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "752",
            "database": "netisp",
            "id": "07052",
            "name": "BALNEARIO CAMBORIU",
            "state": "SC"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "753",
            "database": "netisp",
            "id": "03753",
            "name": "CONTAGEM",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "755",
            "database": "netsul",
            "id": "83755",
            "name": "IBIUNA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "756",
            "database": "netabc",
            "id": "05756",
            "name": "JACAREI",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "757",
            "database": "netisp",
            "id": "07757",
            "name": "ESTANCIA VELHA",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "758",
            "database": "netisp",
            "id": "07758",
            "name": "ESTEIO",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "761",
            "database": "netabc",
            "id": "05761",
            "name": "JAGUARIUNA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "762",
            "database": "netisp",
            "id": "31763",
            "name": "LAGOA DA PRATA",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "763",
            "database": "netisp",
            "id": "04763",
            "name": "TEOFILO OTONI",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "764",
            "database": "netsorocaba",
            "id": "74764",
            "name": "VACARIA",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "765",
            "database": "netsorocaba",
            "id": "05765",
            "name": "JANDIRA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "769",
            "database": "netsorocaba",
            "id": "05769",
            "name": "JAU",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "770",
            "database": "netisp",
            "id": "06770",
            "name": "PINHAIS",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "mixed"
            },
            "code": "771",
            "database": "netisp",
            "id": "63770",
            "name": "TRES RIOS",
            "state": "RJ"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "772",
            "database": "netsorocaba",
            "id": "16772",
            "name": "GUARAPARI",
            "state": "ES"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "775",
            "database": "netsorocaba",
            "id": "76775",
            "name": "INDAIAL",
            "state": "SC"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "778",
            "database": "netsul",
            "id": "03778",
            "name": "CORONEL FABRICIANO",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "780",
            "database": "netsul",
            "id": "04780",
            "name": "TRES CORACOES",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "781",
            "database": "netsul",
            "id": "68780",
            "name": "DOIS IRMAOS",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "mixed"
            },
            "code": "782",
            "database": "netbrasil",
            "id": "19780",
            "name": "FORMOSA",
            "state": "GO"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "786",
            "database": "netsul",
            "id": "55786",
            "name": "FRANCISCO BELTRAO",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "787",
            "database": "netabc",
            "id": "81787",
            "name": "CABREUVA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "790",
            "database": "netsul",
            "id": "53791",
            "name": "ANDIRA",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "791",
            "database": "netabc",
            "id": "05791",
            "name": "LIMEIRA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "793",
            "database": "netabc",
            "id": "87793",
            "name": "SANTA GERTRUDES",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "794",
            "database": "netsorocaba",
            "id": "06794",
            "name": "PONTA GROSSA",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "795",
            "database": "netsorocaba",
            "id": "05795",
            "name": "LORENA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "mixed"
            },
            "code": "797",
            "database": "netisp",
            "id": "40797",
            "name": "NAVIRAI",
            "state": "MS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "798",
            "database": "netsul",
            "id": "05798",
            "name": "LOUVEIRA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "800",
            "database": "netisp",
            "id": "63800",
            "name": "VALENCA",
            "state": "RJ"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "801",
            "database": "netsorocaba",
            "id": "83801",
            "name": "IGARACU DO TIETE",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "802",
            "database": "netsorocaba",
            "id": "02801",
            "name": "ALAGOINHAS",
            "state": "BA"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "803",
            "database": "netisp",
            "id": "04803",
            "name": "UBERABA",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "804",
            "database": "netsorocaba",
            "id": "42803",
            "name": "TANGARA DA SERRA",
            "state": "MT"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "806",
            "database": "netisp",
            "id": "04806",
            "name": "UBERLANDIA",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "807",
            "database": "netisp",
            "id": "09806",
            "name": "TEIXEIRA DE FREITAS",
            "state": "BA"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "808",
            "database": "netabc",
            "id": "87807",
            "name": "SANTA ISABEL",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "810",
            "database": "netabc",
            "id": "05810",
            "name": "MAIRINQUE",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "812",
            "database": "netisp",
            "id": "33812",
            "name": "PARA DE MINAS",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "813",
            "database": "netbrasil",
            "id": "30813",
            "name": "ITABIRA",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "817",
            "database": "netsul",
            "id": "07817",
            "name": "GRAMADO",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "mixed"
            },
            "code": "818",
            "database": "netisp",
            "id": "08818",
            "name": "RONDONOPOLIS",
            "state": "MT"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "819",
            "database": "netsorocaba",
            "id": "75817",
            "name": "CACADOR",
            "state": "SC"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "820",
            "database": "netsorocaba",
            "id": "05820",
            "name": "MARILIA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "821",
            "database": "netsul",
            "id": "04821",
            "name": "VARGINHA",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "822",
            "database": "netisp",
            "id": "33820",
            "name": "PARACATU",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "823",
            "database": "netsorocaba",
            "id": "06823",
            "name": "JUAZEIRO",
            "state": "BA"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "824",
            "database": "netisp",
            "id": "88820",
            "name": "PIUMHI",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "825",
            "database": "netisp",
            "id": "62820",
            "name": "PINHEIRAL",
            "state": "RJ"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "829",
            "database": "netsul",
            "id": "74829",
            "name": "VENANCIO AIRES",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "832",
            "database": "netisp",
            "id": "03832",
            "name": "DIVINOPOLIS",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "833",
            "database": "netabc",
            "id": "05833",
            "name": "MAUA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "834",
            "database": "netisp",
            "id": "04834",
            "name": "VESPASIANO",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "835",
            "database": "netsul",
            "id": "92835",
            "name": "IMBE",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "836",
            "database": "netisp",
            "id": "63835",
            "name": "VASSOURAS",
            "state": "RJ"
        },
        {
            "characteristics": {
                "numberIndicator": "mixed"
            },
            "code": "837",
            "database": "netsul",
            "id": "08837",
            "name": "SINOP",
            "state": "MT"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "838",
            "database": "netsul",
            "id": "08838",
            "name": "SORRISO",
            "state": "MT"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "839",
            "database": "netsul",
            "id": "74837",
            "name": "VERA CRUZ",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "840",
            "database": "netisp",
            "id": "35840",
            "name": "SACRAMENTO",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "843",
            "database": "netisp",
            "id": "05843",
            "name": "ILHEUS",
            "state": "BA"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "844",
            "database": "netisp",
            "id": "86843",
            "name": "PONTAL",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "847",
            "database": "netisp",
            "id": "01847",
            "name": "CAMPINA GRANDE",
            "state": "PB"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "848",
            "database": "netisp",
            "id": "62847",
            "name": "PIRAI",
            "state": "RJ"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "850",
            "database": "netabc",
            "id": "05850",
            "name": "MIRASSOL",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "851",
            "database": "netsul",
            "id": "06851",
            "name": "ROLANDIA",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "852",
            "database": "netisp",
            "id": "02852",
            "name": "FEIRA DE SANTANA",
            "state": "BA"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "853",
            "database": "netsul",
            "id": "74853",
            "name": "VERANOPOLIS",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "854",
            "database": "netisp",
            "id": "88854",
            "name": "TAMBAU",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "856",
            "database": "netabc",
            "id": "05856",
            "name": "MOGI DAS CRUZES",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "857",
            "database": "netsul",
            "id": "58858",
            "name": "RIBEIRAO DO PINHAL",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "mixed"
            },
            "code": "858",
            "database": "netsorocaba",
            "id": "08858",
            "name": "VARZEA GRANDE",
            "state": "MT"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "859",
            "database": "netsorocaba",
            "id": "84859",
            "name": "LARANJAL PAULISTA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "863",
            "database": "netabc",
            "id": "05863",
            "name": "MOGI GUACU",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "865",
            "database": "netabc",
            "id": "05865",
            "name": "MOGI MIRIM",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "mixed"
            },
            "code": "866",
            "database": "netbrasil",
            "id": "21865",
            "name": "SENADOR CANEDO",
            "state": "GO"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "867",
            "database": "netisp",
            "id": "08567",
            "name": "DOURADOS",
            "state": "MS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "868",
            "database": "netsorocaba",
            "id": "75868",
            "name": "CAMBORIU",
            "state": "SC"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "869",
            "database": "netabc",
            "id": "05869",
            "name": "MONGAGUA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "870",
            "database": "netisp",
            "id": "65870",
            "name": "ARIQUEMES",
            "state": "RO"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "871",
            "database": "netsul",
            "id": "08471",
            "name": "VIAMAO",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "872",
            "database": "netsorocaba",
            "id": "82872",
            "name": "EMBU-GUACU",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "mixed"
            },
            "code": "875",
            "database": "netabc",
            "id": "08756",
            "name": "LUCAS DO RIO VERDE",
            "state": "MT"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "877",
            "database": "netsul",
            "id": "60879",
            "name": "WENCESLAU BRAZ",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "882",
            "database": "netsorocaba",
            "id": "05882",
            "name": "MONTE MOR",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "884",
            "database": "netsul",
            "id": "55298",
            "name": "CURITIBA - CABO",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "885",
            "database": "netisp",
            "id": "69884",
            "name": "IGREJINHA",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "886",
            "database": "netisp",
            "id": "81884",
            "name": "CAJAMAR",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "887",
            "database": "netsul",
            "id": "54887",
            "name": "CASTRO",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "mixed"
            },
            "code": "895",
            "database": "netisp",
            "id": "08895",
            "name": "APARECIDA DE GOIANIA",
            "state": "GO"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "898",
            "database": "netisp",
            "id": "65897",
            "name": "CACOAL",
            "state": "RO"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "901",
            "database": "netabc",
            "id": "62901",
            "name": "PORTO REAL",
            "state": "RJ"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "903",
            "database": "netisp",
            "id": "32905",
            "name": "MONTE CARMELO",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "904",
            "database": "netisp",
            "id": "87904",
            "name": "SANTA ROSA DE VITERBO",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "905",
            "database": "netabc",
            "id": "84905",
            "name": "LEME",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "907",
            "database": "netsorocaba",
            "id": "01907",
            "name": "JOAO PESSOA",
            "state": "PB"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "908",
            "database": "netsorocaba",
            "id": "86908",
            "name": "PORTO FERREIRA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "909",
            "database": "netsul",
            "id": "31909",
            "name": "LAVRAS",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "910",
            "database": "netsul",
            "id": "05910",
            "name": "NOVA ODESSA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "911",
            "database": "netisp",
            "id": "04911",
            "name": "CACHOEIRO DE ITAPEMIRIM",
            "state": "ES"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "912",
            "database": "netsul",
            "id": "57908",
            "name": "PAICANDU",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "913",
            "database": "netisp",
            "id": "84913",
            "name": "LENCOIS PAULISTA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "914",
            "database": "netsorocaba",
            "id": "69914",
            "name": "IJUI",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "917",
            "database": "netisp",
            "id": "04917",
            "name": "CARIACICA",
            "state": "ES"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "918",
            "database": "netsul",
            "id": "68918",
            "name": "ELDORADO DO SUL",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "920",
            "database": "netsul",
            "id": "67920",
            "name": "CARLOS BARBOSA",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "923",
            "database": "netisp",
            "id": "06923",
            "name": "SAO JOSE DOS PINHAIS",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "924",
            "database": "netsorocaba",
            "id": "05924",
            "name": "OSASCO",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "925",
            "database": "netbrasil",
            "id": "20923",
            "name": "NOVO GAMA",
            "state": "GO"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "926",
            "database": "netisp",
            "id": "37923",
            "name": "SAO SEBASTIAO DO PARAISO",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "927",
            "database": "netsul",
            "id": "57924",
            "name": "PALMAS",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "930",
            "database": "netisp",
            "id": "03930",
            "name": "GOVERNADOR VALADARES",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "933",
            "database": "netisp",
            "id": "31933",
            "name": "LEOPOLDINA",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "934",
            "database": "netsul",
            "id": "68934",
            "name": "ENCANTADO",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "935",
            "database": "netsul",
            "id": "59935",
            "name": "SAO PEDRO DO IVAI",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "940",
            "database": "netsul",
            "id": "72940",
            "name": "SANTA ROSA",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "941",
            "database": "netisp",
            "id": "86940",
            "name": "POTIRENDABA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "942",
            "database": "netisp",
            "id": "34940",
            "name": "PONTE NOVA",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "945",
            "database": "netisp",
            "id": "30945",
            "name": "ITAMARANDIBA",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "947",
            "database": "netsorocaba",
            "id": "64947",
            "name": "MOSSORO",
            "state": "RN"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "948",
            "database": "netabc",
            "id": "84948",
            "name": "LINS",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "950",
            "database": "netsul",
            "id": "07950",
            "name": "MONTENEGRO",
            "state": "RS"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "951",
            "database": "netabc",
            "id": "83950",
            "name": "IPERO",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "953",
            "database": "netbrasil",
            "id": "05953",
            "name": "AGUAS LINDAS DE GOIAS",
            "state": "GO"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "954",
            "database": "netisp",
            "id": "05954",
            "name": "PAULINIA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "955",
            "database": "netisp",
            "id": "26956",
            "name": "CAPELINHA",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "956",
            "database": "netabc",
            "id": "50954",
            "name": "PETROLINA",
            "state": "PE"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "966",
            "database": "netabc",
            "id": "05966",
            "name": "PEDREIRA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "968",
            "database": "netabc",
            "id": "60968",
            "name": "ANGRA DOS REIS",
            "state": "RJ"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "970",
            "database": "netabc",
            "id": "82970",
            "name": "ESPIRITO SANTO DO PINHAL",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "971",
            "database": "netisp",
            "id": "35971",
            "name": "SANTA CRUZ DE MINAS",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "972",
            "database": "netabc",
            "id": "05972",
            "name": "PERUIBE",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "976",
            "database": "netabc",
            "id": "05976",
            "name": "PINDAMONHANGABA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "987",
            "database": "netisp",
            "id": "85987",
            "name": "OLIMPIA",
            "state": "SP"
        },
        {
            "characteristics": {
                "numberIndicator": "mixed"
            },
            "code": "992",
            "database": "netisp",
            "id": "19992",
            "name": "GURUPI",
            "state": "TO"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "994",
            "database": "netisp",
            "id": "65994",
            "name": "JI-PARANA",
            "state": "RO"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "995",
            "database": "netisp",
            "id": "33995",
            "name": "PASSOS",
            "state": "MG"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "996",
            "database": "netsul",
            "id": "56995",
            "name": "LONDRINA",
            "state": "PR"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "997",
            "database": "netsorocaba",
            "id": "44997",
            "name": "SANTAREM",
            "state": "PA"
        },
        {
            "characteristics": {
                "numberIndicator": "required"
            },
            "code": "998",
            "database": "netsorocaba",
            "id": "62995",
            "name": "QUEIMADOS",
            "state": "RJ"
        }
    ]

# %%
import pandas as pd
import json

# %%
prepared_data = []
for i in regions:
    print(i)
    try:
        json_object = json.loads(i)
        prepared_data.append(json_object)
    except ValueError as e:
        print("error",e)

print("data insignts2 - :",prepared_data[0])

df = pd.DataFrame(prepared_data)
# Out:
# {'characteristics': {'numberIndicator': 'required'}, 'code': '001', 'database': 'netabc', 'id': '61000', 'name': 'ARARUAMA', 'state': 'RJ'}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 5
#       3 print(i)
#       4 try:
# ----> 5     json_object = json.loads(i)
#       6     prepared_data.append(json_object)
#       7 except ValueError as e:
#
# File /usr/local/Cellar/python@3.9/3.9.16/Frameworks/Python.framework/Versions/3.9/lib/python3.9/json/__init__.py:339, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337 else:
#     338     if not isinstance(s, (bytes, bytearray)):
# --> 339         raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     340                         f'not {s.__class__.__name__}')
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
# ...

# %%
# Out:
# '[{"characteristics": {"numberIndicator": "required"}, "code": "001", "database": "netabc", "id": "61000", "name": "ARARUAMA", "state": "RJ"}, {"characteristics": {"numberIndicator": "required"}, "code": "002", "database": "netsul", "id": "00272", "name": "MARABA", "state": "PA"}, {"characteristics": {"numberIndicator": "required"}, "code": "003", "database": "netsp", "id": "88412", "name": "SAO PAULO", "state": "SP"}, {"characteristics": {"numberIndicator": "required"}, "code": "004", "database": "netbrasil", "id": "06139", "name": "SANTOS", "state": "SP"}, {"characteristics": {"numberIndicator": "required"}, "code": "005", "database": "netisp", "id": "06070", "name": "RIBEIRAO PRETO", "state": "SP"}, {"characteristics": {"numberIndicator": "required"}, "code": "006", "database": "netisp", "id": "06158", "name": "SAO JOSE DO RIO PRETO", "state": "SP"}, {"characteristics": {"numberIndicator": "required"}, "code": "007", "database": "netsorocaba", "id": "06201", "name": "SOROCABA", "s
# ...

# %%
df = pd.read_json(json.dumps(regions))

# %%
df.to_csv("./regions.csv")
