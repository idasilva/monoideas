# %%
import pandas as pd
import requests
import io
import gzip
import json
import zlib, json, base64
from io import BytesIO
import io
import gzip
import json

# %%
#!pip install pyspark

# %%
base_url = ("https://data.gharchive.org/2023-01-01-2.json.gz") 



response = requests.get(base_url)
content = response.content

dfs = []
chunksize = 100
for chunk in pd.read_json(io.BytesIO(content),orient="records", lines=True, compression='gzip', chunksize=chunksize):
     dfs.append(chunk)

# %%
df1 = pd.concat(dfs,axis=0)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90693 entries, 0 to 90692
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          90693 non-null  int64
#  1   type        90693 non-null  object
#  2   actor       90693 non-null  object
#  3   repo        90693 non-null  object
#  4   payload     90693 non-null  object
#  5   public      90693 non-null  bool
#  6   created_at  90693 non-null  datetime64[ns, UTC]
#  7   org         22339 non-null  object
# dtypes: bool(1), datetime64[ns, UTC](1), int64(1), object(5)
# memory usage: 4.9+ MB

# %%
len(dfs)
# Out:
# 907

# %%
dfs[0].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1000 non-null   int64
#  1   type        1000 non-null   object
#  2   actor       1000 non-null   object
#  3   repo        1000 non-null   object
#  4   payload     1000 non-null   object
#  5   public      1000 non-null   bool
#  6   created_at  1000 non-null   datetime64[ns, UTC]
#  7   org         262 non-null    object
# dtypes: bool(1), datetime64[ns, UTC](1), int64(1), object(5)
# memory usage: 55.8+ KB

# %%
df
# Out:
#                  id                           type  \
# 0       26163418658                      PushEvent
# 1       26163418659                      PushEvent
# 2       26163418660                    IssuesEvent
# 3       26163418664                     WatchEvent
# 4       26163418665                      PushEvent
# ...             ...                            ...
# 101912  26163700494                      PushEvent
# 101913  26163700498                      PushEvent
# 101914  26163700502              IssueCommentEvent
# 101915  26163700504                      PushEvent
# 101916  26163701098  PullRequestReviewCommentEvent
#
#                                                     actor  \
# 0       {'id': 119809980, 'login': 'ehwu106', 'display...
# 1       {'id': 77187908, 'login': 'Cefqrn', 'display_l...
# 2       {'id': 121737278, 'login': 'LaymooDR', 'displa...
# 3       {'id': 89544871, 'login': 'Aziz403', 'display_...
# 4       {'id': 8517910, 'login': 'LombiqBot', 'display...
# ...                                                   ...
# 101912  {'id': 93773753, 'login': 'BlaaSwe', 'display_...
# 101913  {'id': 110655703, 'login': 'sfj297092319', 'di...
# 101914  {'id': 55374212, 'login': 'GuillaumePrata', 'd...
# 101915  {'id': 35409597, 'login': 'JetBlack011', 'disp...
# 101916  {'id': 17688683, 'login': 'Amazinite', 'displa...
#
#                                                      repo  \
# 0       {'id': 582174284, 'name': 'ehwu106/Gmail-Filte...
# 1       {'id': 583140987, 'name': 'Cefqrn/pyxpr', 'url...
# 2       {'id': 383940088, 'name': 'ShadowMario/FNF-Psy...
# 3       {'id': 2663796, 'name': 'lexik/LexikTranslatio...
# 4       {'id': 410004154, 'name': 'Lombiq/TheBootstrap...
# ...                                                   ...
# 101912  {'id': 568383720, 'name': 'BlaaSwe/Base-Soarin...
# 101913  {'id': 530264309, 'name': 'usahexo/2452bb12a82...
# 101914  {'id': 3234987, 'name': 'tgstation/tgstation',...
# 101915  {'id': 541393257, 'name': 'JetBlack011/convex-...
# 101916  {'id': 32231207, 'name': 'endless-sky/endless-...
#
#                                                   payload  public  \
# 0       {'push_id': 12147229638, 'size': 2, 'distinct_...    True
# 1       {'push_id': 12147229637, 'size': 2, 'distinct_...    True
# 2       {'action': 'opened', 'issue': {'url': 'https:/...    True
# 3                                   {'action': 'started'}    True
# 4       {'push_id': 12147229641, 'size': 0, 'distinct_...    True
# ...                                                   ...     ...
# 101912  {'push_id': 12147404982, 'size': 1, 'distinct_...    True
# 101913  {'push_id': 12147404988, 'size': 1, 'distinct_...    True
# 101914  {'action': 'created', 'issue': {'url': 'https:...    True
# 101915  {'push_id': 12147404989, 'size': 1, 'distinct_...    True
# 101916  {'action': 'created', 'comment': {'url': 'http...    True
#
#                       created_at  \
# 0      2023-01-01 00:00:00+00:00
# 1      2023-01-01 00:00:00+00:00
# 2      2023-01-01 00:00:00+00:00
# 3      2023-01-01 00:00:00+00:00
# 4      2023-01-01 00:00:00+00:00
# ...                          ...
# 101912 2023-01-01 00:59:59+00:00
# 101913 2023-01-01 00:59:59+00:00
# 101914 2023-01-01 00:59:59+00:00
# 101915 2023-01-01 00:59:59+00:00
# 101916 2023-01-01 00:59:05+00:00
#
#                                                       org
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3       {'id': 568486, 'login': 'lexik', 'gravatar_id'...
# 4       {'id': 8158177, 'login': 'Lombiq', 'gravatar_i...
# ...                                                   ...
# 101912                                                NaN
# 101913  {'id': 110656312, 'login': 'usahexo', 'gravata...
# 101914  {'id': 1363778, 'login': 'tgstation', 'gravata...
# 101915                                                NaN
# 101916  {'id': 11450262, 'login': 'endless-sky', 'grav...
#
# [101917 rows x 8 columns]

# %%
len(df)
# Out:
# 101917

# %%
df.fillna('', inplace=True)

# %%
pandas_to_frame = df.to_dict('records')

# %%
pandas_to_frame[0]
# Out:
# {'id': 26163418658,
#  'type': 'PushEvent',
#  'actor': {'id': 119809980,
#   'login': 'ehwu106',
#   'display_login': 'ehwu106',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/ehwu106',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/119809980?'},
#  'repo': {'id': 582174284,
#   'name': 'ehwu106/Gmail-Filter-Solution',
#   'url': 'https://api.github.com/repos/ehwu106/Gmail-Filter-Solution'},
#  'payload': {'push_id': 12147229638,
#   'size': 2,
#   'distinct_size': 2,
#   'ref': 'refs/heads/main',
#   'head': '8fbcb0a5be7f1ae98c620ffc445f8212da279c4b',
#   'before': '27e76fd2920c98cf825daefa9469cb202944d96d',
#   'commits': [{'sha': '01882b15808c6cc63f4075eea105de4f608e23aa',
#     'author': {'email': 'howard.wu@travasecurity.com', 'name': 'Howard Wu'},
#     'message': 'pushing',
#     'distinct': True,
#     'url': 'https://api.github.com/repos/ehwu106/Gmail-Filter-Solution/commits/01882b15808c6cc63f4075eea105de4f608e23aa'},
#    {'sha': '8fbcb0a5be7f1ae98c620ffc445f8212da279c4b',
#     'author': {'email': 'hwu106@ucsc.edu', 'name': 'hwu106'},
#     'message': 'push',
#     'distinct': True,
#     'url': 'https://api.github.com/repos/ehwu106/Gmail-Filter-Solution/commits/8fbcb0a5be7f1ae98c620ffc445f8212da279c4b'}]},
#  'public': True,
#  'created_at': Timestamp('2023-01-01 00:00:00+0000', tz='UTC'),
#  'org': ''}

# %%
for index, value in enumerate(pandas_to_frame):
        pandas_to_frame[index]["actor_id"] =  pandas_to_frame[index]["actor"]['id']
        pandas_to_frame[index]["actor_login"] =  pandas_to_frame[index]["actor"]['login']
        pandas_to_frame[index]["actor_display_login"] =  pandas_to_frame[index]["actor"]['display_login']
        pandas_to_frame[index]["actor_gravatar_id"] =  pandas_to_frame[index]["actor"]['gravatar_id']
        pandas_to_frame[index]["actor_url"] =  pandas_to_frame[index]["actor"]['url']
        pandas_to_frame[index]["actor_avatar_url"] =  pandas_to_frame[index]["actor"]['avatar_url']

# %%
for index, value in enumerate(pandas_to_frame):
    pandas_to_frame[index]["repo_id"] =   pandas_to_frame[index]["repo"]['id']
    pandas_to_frame[index]["repo_name"] =   pandas_to_frame[index]["repo"]['name']
    pandas_to_frame[index]["repo_url"] =   pandas_to_frame[index]["repo"]['url']

# %%
for index, value in enumerate(pandas_to_frame):
    if "id" in pandas_to_frame[index]["org"]:
        pandas_to_frame[index]["org_id"] =  pandas_to_frame[index]["org"]['id']
        pandas_to_frame[index]["org_login"] =  pandas_to_frame[index]["org"]['login']
        pandas_to_frame[index]["org_gravatar_id"] =  pandas_to_frame[index]["org"]['gravatar_id']
        pandas_to_frame[index]["org_url"] =  pandas_to_frame[index]["org"]['url']
        pandas_to_frame[index]["org_avatar_url"] =  pandas_to_frame[index]["org"]['avatar_url']

# %%
df = pd.DataFrame(pandas_to_frame)

# %%
df.head(1)
# Out:
#             id       type                                              actor  \
# 0  26163418658  PushEvent  {'id': 119809980, 'login': 'ehwu106', 'display...
#
#                                                 repo  \
# 0  {'id': 582174284, 'name': 'ehwu106/Gmail-Filte...
#
#                                              payload  public  \
# 0  {'push_id': 12147229638, 'size': 2, 'distinct_...    True
#
#                  created_at org   actor_id actor_login  ...  \
# 0 2023-01-01 00:00:00+00:00      119809980     ehwu106  ...
#
#                               actor_url  \
# 0  https://api.github.com/users/ehwu106
#
#                                     actor_avatar_url    repo_id  \
# 0  https://avatars.githubusercontent.com/u/119809...  582174284
#
#                        repo_name  \
# 0  ehwu106/Gmail-Filter-Solution
#
#                                             repo_url org_id org_login  \
# 0  https://api.github.com/repos/ehwu106/Gmail-Fil...    NaN       NaN
#
#    org_gravatar_id org_url org_avatar_url
# 0              NaN     NaN            NaN
#
# [1 rows x 22 columns]

# %%
del df["repo"]
del df["actor"]
del df["org"]
del df["payload"]

# %%
df.head(100)
# Out:
#              id         type  public                created_at   actor_id  \
# 0   26163418658    PushEvent    True 2023-01-01 00:00:00+00:00  119809980
# 1   26163418659    PushEvent    True 2023-01-01 00:00:00+00:00   77187908
# 2   26163418660  IssuesEvent    True 2023-01-01 00:00:00+00:00  121737278
# 3   26163418664   WatchEvent    True 2023-01-01 00:00:00+00:00   89544871
# 4   26163418665    PushEvent    True 2023-01-01 00:00:00+00:00    8517910
# ..          ...          ...     ...                       ...        ...
# 95  26163418929    PushEvent    True 2023-01-01 00:00:03+00:00  108680395
# 96  26163418933    PushEvent    True 2023-01-01 00:00:03+00:00  120438850
# 97  26163418938  CreateEvent    True 2023-01-01 00:00:03+00:00   41898282
# 98  26163418939  IssuesEvent    True 2023-01-01 00:00:03+00:00   20752424
# 99  26163418940    PushEvent    True 2023-01-01 00:00:03+00:00  119910615
#
#             actor_login actor_display_login actor_gravatar_id  \
# 0               ehwu106             ehwu106
# 1                Cefqrn              Cefqrn
# 2              LaymooDR            LaymooDR
# 3               Aziz403             Aziz403
# 4             LombiqBot           LombiqBot
# ..                  ...                 ...               ...
# 95           richardaeh          richardaeh
# 96             19920513            19920513
# 97  github-actions[bot]      github-actions
# 98             jasperan            jasperan
# 99        happyfish2024       happyfish2024
#
#                                            actor_url  \
# 0               https://api.github.com/users/ehwu106
# 1                https://api.github.com/users/Cefqrn
# 2              https://api.github.com/users/LaymooDR
# 3               https://api.github.com/users/Aziz403
# 4             https://api.github.com/users/LombiqBot
# ..                                               ...
# 95           https://api.github.com/users/richardaeh
# 96             https://api.github.com/users/19920513
# 97  https://api.github.com/users/github-actions[bot]
# 98             https://api.github.com/users/jasperan
# 99        https://api.github.com/users/happyfish2024
#
#                                      actor_avatar_url    repo_id  \
# 0   https://avatars.githubusercontent.com/u/119809...  582174284
# 1   https://avatars.githubusercontent.com/u/77187908?  583140987
# 2   https://avatars.githubusercontent.com/u/121737...  383940088
# 3   https://avatars.githubusercontent.com/u/89544871?    2663796
# 4    https://avatars.githubusercontent.com/u/8517910?  410004154
# ..                                                ...        ...
# 95  https://avatars.githubusercontent.com/u/108680...  510397814
# 96  https://avatars.githubusercontent.com/u/120438...  583676719
# 97  https://avatars.githubusercontent.com/u/41898282?  477099151
# 98  https://avatars.githubusercontent.com/u/20752424?  161610594
# 99  https://avatars.githubusercontent.com/u/119910...  575386595
#
#                           repo_name  \
# 0     ehwu106/Gmail-Filter-Solution
# 1                      Cefqrn/pyxpr
# 2       ShadowMario/FNF-PsychEngine
# 3      lexik/LexikTranslationBundle
# 4          Lombiq/TheBootstrapTheme
# ..                              ...
# 95  richardaeh/richardaeh.github.io
# 96                     19920513/djy
# 97     alefnode/opensuse-gsi-images
# 98            jasperan/github-utils
# 99               happyfish2024/mins
#
#                                              repo_url     org_id org_login  \
# 0   https://api.github.com/repos/ehwu106/Gmail-Fil...        NaN       NaN
# 1           https://api.github.com/repos/Cefqrn/pyxpr        NaN       NaN
# 2   https://api.github.com/repos/ShadowMario/FNF-P...        NaN       NaN
# 3   https://api.github.com/repos/lexik/LexikTransl...   568486.0     lexik
# 4   https://api.github.com/repos/Lombiq/TheBootstr...  8158177.0    Lombiq
# ..                                                ...        ...       ...
# 95  https://api.github.com/repos/richardaeh/richar...        NaN       NaN
# 96          https://api.github.com/repos/19920513/djy        NaN       NaN
# 97  https://api.github.com/repos/alefnode/opensuse...        NaN       NaN
# 98  https://api.github.com/repos/jasperan/github-u...        NaN       NaN
# 99    https://api.github.com/repos/happyfish2024/mins        NaN       NaN
#
#    org_gravatar_id                             org_url  \
# 0              NaN                                 NaN
# 1              NaN                                 NaN
# 2              NaN                                 NaN
# 3                    https://api.github.com/orgs/lexik
# 4                   https://api.github.com/orgs/Lombiq
# ..             ...                                 ...
# 95             NaN                                 NaN
# 96             NaN                                 NaN
# 97             NaN                                 NaN
# 98             NaN                                 NaN
# 99             NaN                                 NaN
#
#                                       org_avatar_url
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3    https://avatars.githubusercontent.com/u/568486?
# 4   https://avatars.githubusercontent.com/u/8158177?
# ..                                               ...
# 95                                               NaN
# 96                                               NaN
# 97                                               NaN
# 98                                               NaN
# 99                                               NaN
#
# [100 rows x 18 columns]

# %%
new_df = df[(df['org_id'] == 21003710.0) | (df['org_id'] == 13455738.0) ].head(100)

# %%
len(new_df)
# Out:
# 20

# %%
new_df.head(1)
# Out:
#                id              type  public                created_at  \
# 4931  26163435072  PullRequestEvent    True 2023-01-01 00:02:32+00:00
#
#       actor_id          actor_login actor_display_login actor_gravatar_id  \
# 4931  41898282  github-actions[bot]      github-actions
#
#                                              actor_url  \
# 4931  https://api.github.com/users/github-actions[bot]
#
#                                        actor_avatar_url    repo_id  \
# 4931  https://avatars.githubusercontent.com/u/41898282?  246634306
#
#              repo_name                                       repo_url  \
# 4931  pytorch/TensorRT  https://api.github.com/repos/pytorch/TensorRT
#
#           org_id org_login org_gravatar_id  \
# 4931  21003710.0   pytorch
#
#                                   org_url  \
# 4931  https://api.github.com/orgs/pytorch
#
#                                          org_avatar_url
# 4931  https://avatars.githubusercontent.com/u/21003710?

# %%
new_df['created_at'] = pd.to_datetime(new_df["created_at"]).dt.date
new_df['created_at'] =new_df["created_at"].astype(str)

# %%
new_df['public'] = new_df['public'].astype(str)

# %%
new_df.head(1)
# Out:
#                id              type public  created_at  actor_id  \
# 4931  26163435072  PullRequestEvent   True  2023-01-01  41898282
#
#               actor_login actor_display_login actor_gravatar_id  \
# 4931  github-actions[bot]      github-actions
#
#                                              actor_url  \
# 4931  https://api.github.com/users/github-actions[bot]
#
#                                        actor_avatar_url    repo_id  \
# 4931  https://avatars.githubusercontent.com/u/41898282?  246634306
#
#              repo_name                                       repo_url  \
# 4931  pytorch/TensorRT  https://api.github.com/repos/pytorch/TensorRT
#
#           org_id org_login org_gravatar_id  \
# 4931  21003710.0   pytorch
#
#                                   org_url  \
# 4931  https://api.github.com/orgs/pytorch
#
#                                          org_avatar_url
# 4931  https://avatars.githubusercontent.com/u/21003710?

# %%
#!pip install  requests

# %%
new_df.to_csv('./primeira-massa.csv')
